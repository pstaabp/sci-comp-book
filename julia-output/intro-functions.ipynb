# %%
isOdd(n::Integer) = mod(n,2)==1
# Out:
# isOdd (generic function with 1 method)

# %%
isOdd(3.5)
# Out:
# MethodError: no method matching isOdd(::Float64)
#
# The function `isOdd` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   isOdd(!Matched::Integer)
#
#    @ Main ~/code/sci-comp-book/julia-output/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:1
#
#
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/code/sci-comp-book/julia-output/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:1

# %%
theMean(x,y) = 0.5*(x+y)
# Out:
# theMean (generic function with 1 method)

# %%
theMean(x::Real, y::Real) = 0.5*(x+y)
# Out:
# theMean (generic function with 2 methods)

# %%
theMean(x::Real, y::Real, z::Real) = (x+y+z)/3
# Out:
# theMean (generic function with 3 methods)

# %%
methods(theMean)
# Out:
# # 3 methods for generic function "theMean" from Main:
#  [1] theMean(x::Real, y::Real)
#      @ ~/code/sci-comp-book/julia-output/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1
#  [2] theMean(x, y)
#      @ ~/code/sci-comp-book/julia-output/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:1
#  [3] theMean(x::Real, y::Real, z::Real)
#      @ ~/code/sci-comp-book/julia-output/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:1

# %%
theMean(str::String) =  "This should return the definition of $str"
# Out:
# theMean (generic function with 4 methods)

# %%
theMean("defintion")
# Out:
# "This should return the definition of defintion"

# %%
methods(+)
# Out:
# # 197 methods for generic function "+" from Base:
#    [1] +(x::Bool, z::Complex{Bool})
#      @ complex.jl:308
#    [2] +(x::Bool, y::Bool)
#      @ bool.jl:166
#    [3] +(x::Bool)
#      @ bool.jl:163
#    [4] +(x::Bool, z::Complex)
#      @ complex.jl:315
#    [5] +(x::Real, z::Complex{Bool})
#      @ complex.jl:322
#    [6] +(x::Bool, y::T) where T<:AbstractFloat
#      @ bool.jl:173
#    [7] +(x::Dates.CompoundPeriod, y::Dates.CompoundPeriod)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:335
#    [8] +(x::Dates.CompoundPeriod, y::Dates.Period)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:333
#    [9] +(x::Dates.CompoundPeriod, y::Dates.TimeType)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:363
#   [10] +(level::Base.CoreLogging.LogLevel, inc::Integer)
#      @ Base.CoreLogging logging/logging.jl:132
#   [11] +(B::BitMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:151
#   [12] +(dt::Dates.Date, t::Dates.Time)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:21
#   [13] +(dt::Dates.Date, y::Dates.Year)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:29
#   [14] +(dt::Dates.Date, z::Dates.Month)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:56
#   [15] +(x::Dates.Date, y::Dates.Quarter)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:75
#   [16] +(x::Dates.Date, y::Dates.Week)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:79
#   [17] +(x::Dates.Date, y::Dates.Day)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:81
#   [18] +(t::Dates.Time, dt::Dates.Date)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:22
#   [19] +(x::Dates.Time, y::Dates.TimePeriod)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:85
#   [20] +(dt::Dates.DateTime, y::Dates.Year)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:25
#   [21] +(dt::Dates.DateTime, z::Dates.Month)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:49
#   [22] +(x::Dates.DateTime, y::Dates.Quarter)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:77
#   [23] +(x::Dates.DateTime, y::Dates.Period)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:83
#   [24] +(x::BigInt, y::BigInt)
#      @ Base.GMP gmp.jl:496
#   [25] +(a::BigInt, b::BigInt, c::BigInt)
#      @ Base.GMP gmp.jl:536
#   [26] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt)
#      @ Base.GMP gmp.jl:537
#   [27] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt)
#      @ Base.GMP gmp.jl:538
#   [28] +(x::BigInt, y::BigInt, rest::BigInt...)
#      @ Base.GMP gmp.jl:678
#   [29] +(c::BigInt, x::BigFloat)
#      @ Base.MPFR mpfr.jl:527
#   [30] +(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.GMP gmp.jl:544
#   [31] +(x::BigInt, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.GMP gmp.jl:550
#   [32] +(z::Complex{Bool}, x::Bool)
#      @ complex.jl:309
#   [33] +(z::Complex{Bool}, x::Real)
#      @ complex.jl:323
#   [34] +(z::Complex, x::Bool)
#      @ complex.jl:316
#   [35] +(a::Pkg.Resolve.VersionWeight, b::Pkg.Resolve.VersionWeight)
#      @ Pkg.Resolve ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Pkg/src/Resolve/versionweights.jl:22
#   [36] +(x::BigFloat, c::BigInt)
#      @ Base.MPFR mpfr.jl:522
#   [37] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat)
#      @ Base.MPFR mpfr.jl:678
#   [38] +(x::BigFloat, y::BigFloat)
#      @ Base.MPFR mpfr.jl:491
#   [39] +(a::BigFloat, b::BigFloat, c::BigFloat)
#      @ Base.MPFR mpfr.jl:665
#   [40] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat)
#      @ Base.MPFR mpfr.jl:671
#   [41] +(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.MPFR mpfr.jl:498
#   [42] +(x::BigFloat, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.MPFR mpfr.jl:506
#   [43] +(x::BigFloat, c::Union{Float16, Float32, Float64})
#      @ Base.MPFR mpfr.jl:514
#   [44] +(a::Pkg.Resolve.FieldValue, b::Pkg.Resolve.FieldValue)
#      @ Pkg.Resolve ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Pkg/src/Resolve/fieldvalues.jl:43
#   [45] +(x::Rational{BigInt}, y::Rational{BigInt})
#      @ Base.GMP.MPQ gmp.jl:1056
#   [46] +(::Missing, ::Missing)
#      @ missing.jl:122
#   [47] +(::Missing)
#      @ missing.jl:101
#   [48] +(x::Missing, y::Dates.AbstractTime)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:91
#   [49] +(::Missing, ::Number)
#      @ missing.jl:123
#   [50] +(A::Array, Bs::Array...)
#      @ arraymath.jl:12
#   [51] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:230
#   [52] +(B::LinearAlgebra.Tridiagonal, A::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra none:0
#   [53] +(B::LinearAlgebra.Tridiagonal, A::LinearAlgebra.Diagonal)
#      @ LinearAlgebra none:0
#   [54] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:181
#   [55] +(x::LinearAlgebra.Tridiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#   [56] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/tridiag.jl:784
#   [57] +(r::AbstractRange{<:Dates.TimeType}, x::Dates.Period)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/ranges.jl:65
#   [58] +(A::LinearAlgebra.UpperHessenberg, B::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:113
#   [59] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [60] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [61] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [62] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [63] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [64] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [65] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:120
#   [66] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/tridiag.jl:215
#   [67] +(B::LinearAlgebra.SymTridiagonal, A::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra none:0
#   [68] +(B::LinearAlgebra.SymTridiagonal, A::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra none:0
#   [69] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Symmetric)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:539
#   [70] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:235
#   [71] +(x::LinearAlgebra.SymTridiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#   [72] +(B::LinearAlgebra.SymTridiagonal, A::LinearAlgebra.Diagonal)
#      @ LinearAlgebra none:0
#   [73] +(A::LinearAlgebra.SymTridiagonal{var"#s4931", V} where {var"#s4931"<:Real, V<:AbstractVector{var"#s4931"}}, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:541
#   [74] +(x::AbstractIrrational, y::AbstractIrrational)
#      @ irrationals.jl:164
#   [75] +(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/diagonal.jl:250
#   [76] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:185
#   [77] +(B::LinearAlgebra.Diagonal, A::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra none:0
#   [78] +(D::LinearAlgebra.Diagonal, S::LinearAlgebra.Symmetric)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/diagonal.jl:254
#   [79] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:245
#   [80] +(x::LinearAlgebra.Diagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#   [81] +(D::LinearAlgebra.Diagonal{var"#s4933", V} where {var"#s4933"<:Real, V<:AbstractVector{var"#s4933"}}, H::LinearAlgebra.Hermitian)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/diagonal.jl:260
#   [82] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:164
#   [83] +(x::Ptr, y::Integer)
#      @ pointer.jl:316
#   [84] +(A::LinearAlgebra.UnitLowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UnitLowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:762
#   [85] +(A::LinearAlgebra.UnitLowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.LowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:762
#   [86] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:746
#   [87] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:744
#   [88] +(A::LinearAlgebra.UpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UnitUpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:765
#   [89] +(A::LinearAlgebra.UpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:765
#   [90] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:741
#   [91] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:739
#   [92] +(A::LinearAlgebra.UnitUpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UnitUpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:765
#   [93] +(A::LinearAlgebra.UnitUpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UpperTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:765
#   [94] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:745
#   [95] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:743
#   [96] +(A::LinearAlgebra.LowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.UnitLowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:762
#   [97] +(A::LinearAlgebra.LowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T}, B::LinearAlgebra.LowerTriangular{<:Any, <:Union{LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, StridedArray{T, 2}} where T})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:762
#   [98] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:742
#   [99] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:740
#  [100] +(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:747
#  [101] +(x::Integer, y::AbstractChar)
#      @ char.jl:247
#  [102] +(y::Integer, x::Rational)
#      @ rational.jl:380
#  [103] +(x::Integer, y::Ptr)
#      @ pointer.jl:318
#  [104] +(c::Union{Int16, Int32, Int64, Int8}, x::BigInt)
#      @ Base.GMP gmp.jl:551
#  [105] +(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt)
#      @ Base.GMP gmp.jl:545
#  [106] +(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8}
#      @ int.jl:87
#  [107] +(a::Integer, b::Integer)
#      @ int.jl:1009
#  [108] +(x::Number, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:145
#  [109] +(::Number, ::Missing)
#      @ missing.jl:124
#  [110] +(x::Number, y::Base.TwicePrecision)
#      @ twiceprecision.jl:292
#  [111] +(z::Complex)
#      @ complex.jl:295
#  [112] +(x::Rational)
#      @ rational.jl:330
#  [113] +(x::Number)
#      @ operators.jl:533
#  [114] +(z::Complex, w::Complex)
#      @ complex.jl:297
#  [115] +(x::Rational, y::Rational)
#      @ rational.jl:344
#  [116] +(x::T, y::T) where T<:Union{Float16, Float32, Float64}
#      @ float.jl:491
#  [117] +(x::T, y::T) where T<:Number
#      @ promotion.jl:625
#  [118] +(x::Real, z::Complex)
#      @ complex.jl:334
#  [119] +(z::Complex, x::Real)
#      @ complex.jl:335
#  [120] +(y::AbstractFloat, x::Bool)
#      @ bool.jl:176
#  [121] +(x::Rational, y::Integer)
#      @ rational.jl:373
#  [122] +(c::Union{Float16, Float32, Float64}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:519
#  [123] +(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:511
#  [124] +(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:503
#  [125] +(x::Number, y::Number)
#      @ promotion.jl:429
#  [126] +(S::LinearAlgebra.Symmetric, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/diagonal.jl:257
#  [127] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:540
#  [128] +(A::LinearAlgebra.Symmetric{var"#s4932", S} where {var"#s4932"<:Real, S<:(AbstractMatrix{<:var"#s4932"})}, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:538
#  [129] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.Symmetric)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:529
#  [130] +(J::LinearAlgebra.UniformScaling, B::BitMatrix)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:152
#  [131] +(B::LinearAlgebra.UniformScaling, A::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra none:0
#  [132] +(J::LinearAlgebra.UniformScaling, F::LinearAlgebra.Hessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:562
#  [133] +(B::LinearAlgebra.UniformScaling, A::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra none:0
#  [134] +(x::LinearAlgebra.UniformScaling, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#  [135] +(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:150
#  [136] +(B::LinearAlgebra.UniformScaling, A::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra none:0
#  [137] +(J::LinearAlgebra.UniformScaling, x::Number)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:144
#  [138] +(B::LinearAlgebra.UniformScaling, A::LinearAlgebra.Diagonal)
#      @ LinearAlgebra none:0
#  [139] +(J::LinearAlgebra.UniformScaling, A::AbstractMatrix)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:153
#  [140] +(J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:149
#  [141] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:91
#  [142] +(UL::LinearAlgebra.UnitLowerTriangular, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:181
#  [143] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:91
#  [144] +(x::LinearAlgebra.UpperTriangular, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#  [145] +(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T
#      @ twiceprecision.jl:294
#  [146] +(x::Base.TwicePrecision, y::Base.TwicePrecision)
#      @ twiceprecision.jl:299
#  [147] +(x::Base.TwicePrecision, y::Number)
#      @ twiceprecision.jl:288
#  [148] +(r1::LinRange{T}, r2::LinRange{T}) where T
#      @ range.jl:1448
#  [149] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:200
#  [150] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/bidiag.jl:396
#  [151] +(x::LinearAlgebra.Bidiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#  [152] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:99
#  [153] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:215
#  [154] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:99
#  [155] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:99
#  [156] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:99
#  [157] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:240
#  [158] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:149
#  [159] +(A::BitArray, B::BitArray)
#      @ bitarray.jl:1184
#  [160] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:91
#  [161] +(x::LinearAlgebra.UnitUpperTriangular, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:121
#  [162] +(UL::LinearAlgebra.UnitUpperTriangular, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:181
#  [163] +(x::T, y::Integer) where T<:AbstractChar
#      @ char.jl:237
#  [164] +(r1::StepRangeLen{T, R}, r2::StepRangeLen{T, R}) where {R<:Base.TwicePrecision, T}
#      @ twiceprecision.jl:624
#  [165] +(r1::StepRangeLen{T, S}, r2::StepRangeLen{T, S}) where {T, S}
#      @ range.jl:1464
#  [166] +(x::Dates.Instant)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:4
#  [167] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:354
#  [168] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period, d::Dates.Period...)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:355
#  [169] +(x::Dates.TimeType, y::Dates.CompoundPeriod)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:357
#  [170] +(x::Dates.TimeType)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:8
#  [171] +(y::Dates.TimeType, x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:18
#  [172] +(F::LinearAlgebra.Hessenberg, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/hessenberg.jl:561
#  [173] +(x::Dates.AbstractTime, y::Missing)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:90
#  [174] +(index1::CartesianIndex{N}, index2::CartesianIndex{N}) where N
#      @ Base.IteratorsMD multidimensional.jl:120
#  [175] +(r1::OrdinalRange, r2::OrdinalRange)
#      @ range.jl:1441
#  [176] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/special.jl:91
#  [177] +(x::AbstractArray{<:Dates.TimeType}, y::Union{Dates.CompoundPeriod, Dates.Period})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:6
#  [178] +(A::LinearAlgebra.Hermitian, J::LinearAlgebra.UniformScaling{<:Complex})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:195
#  [179] +(A::AbstractMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/uniformscaling.jl:214
#  [180] +(H::LinearAlgebra.Hermitian, D::LinearAlgebra.Diagonal{var"#s4933", V} where {var"#s4933"<:Real, V<:AbstractVector{var"#s4933"}})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/diagonal.jl:263
#  [181] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.SymTridiagonal{var"#s4930", V} where {var"#s4930"<:Real, V<:AbstractVector{var"#s4930"}})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:542
#  [182] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Symmetric{var"#s4933", S} where {var"#s4933"<:Real, S<:(AbstractMatrix{<:var"#s4933"})})
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:537
#  [183] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/LinearAlgebra/src/symmetric.jl:529
#  [184] +(X::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}}, Y::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:62
#  [185] +(r1::Union{LinRange, OrdinalRange, StepRangeLen}, r2::Union{LinRange, OrdinalRange, StepRangeLen})
#      @ range.jl:1457
#  [186] +(A::AbstractArray, B::AbstractArray)
#      @ arraymath.jl:6
#  [187] +(x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:55
#  [188] +(x::AbstractArray{<:Number})
#      @ abstractarraymath.jl:221
#  [189] +(x::P, y::P) where P<:Dates.Period
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:75
#  [190] +(x::Dates.Period, y::Dates.Period)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:332
#  [191] +(y::Dates.Period, x::Dates.CompoundPeriod)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:334
#  [192] +(y::Dates.Period, x::Dates.TimeType)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/arithmetic.jl:87
#  [193] +(x::Dates.Period, r::AbstractRange{<:Dates.TimeType})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/ranges.jl:64
#  [194] +(x::Union{Dates.CompoundPeriod, Dates.Period})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/periods.jl:343
#  [195] +(x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}}, y::Dates.TimeType)
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:10
#  [196] +(y::Union{Dates.CompoundPeriod, Dates.Period}, x::AbstractArray{<:Dates.TimeType})
#      @ Dates ~/.julia/juliaup/julia-1.11.0-rc2+0.aarch64.apple.darwin14/share/julia/stdlib/v1.11/Dates/src/deprecated.jl:14
#  [197] +(a, b, c, xs...)
#      @ operators.jl:596

# %%
(1+2im)+true
# Out:
# 2 + 2im

# %%
x=3
function f()
  local x=2
  x
end
f()
# Out:
# 2

# %%
x=3
function g()
	global x
	x += 1
end
# Out:
# g (generic function with 1 method)

# %%
g()
# Out:
# 4

# %%
x
# Out:
# 4
